# %% [markdown]
# ***GENERATED CODE FOR npsink PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO WRITE DATA.***

# %%
import requests
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class NumtraConnector:

    def put(inStages, inStagesData, stageId, spark, config):
        path = eval(config)['url']
        baseType = eval(config)['baseType']
        results_url = eval(config)['results_url']
        eval(config)['server']
        originalfile = eval(config)['orignalKey']

        args = {
            'url': path,
            'baseType': baseType,
            'originalfile': originalfile
        }
        response = requests.post(results_url, args)
        return response

# %% [markdown]
# ***READING DATAFRAME***

# %%
#%run npsinkHooks.ipynb
try:
	#sourcePreExecutionHook()

	bostontrain = HDFSConnector.fetch(spark, "{'url': '/FileStore/platform/uploadedSourceFiles/1614597566822_BostonTrain.csv', 'file_type': 'Delimeted', 'delimiter': ',', 'is_header': 'Use Header Line', 'FilePath': '/numtra sink/BostonTrain.csv', 'filename': '1614597566822_BostonTrain.csv', 'viewFileName': 'BostonTrain.csv', 'results_url': 'http://localhost:4040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***WRITING DATAFRAME***

# %%
#%run npsinkHooks.ipynb
try:
	#sinkPreExecutionHook()

	numtrasink = NumtraConnector.fetch(spark, "{'samplefile': '/FileStore/platform/sampleData/6045bc8bea81f940ae3d968b/part-00000-d1eb7622-cc15-490b-90ca-5f1729986faf-c000.csv', 'samplecount': 506, 'originalcount': 506, 'orignalKey': '/FileStore/platform/uploadedSourceFiles/1614597566822_BostonTrain.csv', 'pathOnly': '/numtra sink', 'originalfile': '/numtra sink', 'original_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9985', 'field': 'CRIM', 'alias': 'CRIM', 'position': '1', 'type': 'CRIM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9986', 'field': 'ZN', 'alias': 'ZN', 'position': '2', 'type': 'ZN'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9987', 'field': 'INDUS', 'alias': 'INDUS', 'position': '3', 'type': 'INDUS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9988', 'field': 'CHAS', 'alias': 'CHAS', 'position': '4', 'type': 'CHAS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9989', 'field': 'NOX', 'alias': 'NOX', 'position': '5', 'type': 'NOX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b998a', 'field': 'RM', 'alias': 'RM', 'position': '6', 'type': 'RM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b998b', 'field': 'AGE', 'alias': 'AGE', 'position': '7', 'type': 'AGE'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b998c', 'field': 'DIS', 'alias': 'DIS', 'position': '8', 'type': 'DIS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b998d', 'field': 'RAD', 'alias': 'RAD', 'position': '9', 'type': 'RAD'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b998e', 'field': 'TAX', 'alias': 'TAX', 'position': '10', 'type': 'TAX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b998f', 'field': 'PTRATIO', 'alias': 'PTRATIO', 'position': '11', 'type': 'PTRATIO'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9990', 'field': 'B', 'alias': 'B', 'position': '12', 'type': 'B'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9991', 'field': 'LSTAT', 'alias': 'LSTAT', 'position': '13', 'type': 'LSTAT'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9992', 'field': 'MEDV', 'alias': 'MEDV', 'position': '14', 'type': 'MEDV'}], 'actual_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9977', 'field': 'CRIM', 'alias': 'CRIM', 'position': '1', 'type': 'CRIM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9978', 'field': 'ZN', 'alias': 'ZN', 'position': '2', 'type': 'ZN'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9979', 'field': 'INDUS', 'alias': 'INDUS', 'position': '3', 'type': 'INDUS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b997a', 'field': 'CHAS', 'alias': 'CHAS', 'position': '4', 'type': 'CHAS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b997b', 'field': 'NOX', 'alias': 'NOX', 'position': '5', 'type': 'NOX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b997c', 'field': 'RM', 'alias': 'RM', 'position': '6', 'type': 'RM'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b997d', 'field': 'AGE', 'alias': 'AGE', 'position': '7', 'type': 'AGE'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b997e', 'field': 'DIS', 'alias': 'DIS', 'position': '8', 'type': 'DIS'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b997f', 'field': 'RAD', 'alias': 'RAD', 'position': '9', 'type': 'RAD'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9980', 'field': 'TAX', 'alias': 'TAX', 'position': '10', 'type': 'TAX'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9981', 'field': 'PTRATIO', 'alias': 'PTRATIO', 'position': '11', 'type': 'PTRATIO'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9982', 'field': 'B', 'alias': 'B', 'position': '12', 'type': 'B'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9983', 'field': 'LSTAT', 'alias': 'LSTAT', 'position': '13', 'type': 'LSTAT'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '6045c2b397e52478469b9984', 'field': 'MEDV', 'alias': 'MEDV', 'position': '14', 'type': 'MEDV'}], 'server': 'http://216.168.41.46:3201', 'url': '/numtraPlatform/NumtraPlatformV2/numtra sink/sink.csv', 'delimiter': ',', 'file_type': 'Delimeted', 'filename': 'sink', 'is_header': 'Use Header Line', 'results_url': 'http://localhost:4040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)
